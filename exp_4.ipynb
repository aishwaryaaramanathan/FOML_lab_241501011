# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryaaramanathan/FOML_lab_241501011/blob/main/exp_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
input_value=np.array ([[0,0] ,[0,1], [1,1], [1,0]])
input_value.shape
# Out:
# (4, 2)

# %%
output = np.array([0,0,1,0])
output = output.reshape(4,1)
output.shape
# Out:
# (4, 1)

# %%
weights=np.array([[0.1],[0.3]])
weights
# Out:
# array([[0.1],
#        [0.3]])

# %%
bias = 0.2
def sigmoid_func(x):
  return 1/(1+np.exp(-x))
def der(x):
  return sigmoid_func(x)*(1 - sigmoid_func(x))
for epochs in range(15000):
  input_arr = input_value

weighted_sum=np.dot(input_arr,weights)+bias
first_output=sigmoid_func(weighted_sum)
error=first_output - output
total_error=np.square(np.subtract(first_output,output)).mean()
first_der=error
second_der=der(first_output)
derivative=first_der*second_der
t_input = input_value.T
final_derivative=np.dot(t_input,derivative)
weights=weights - (0.05 * final_derivative)
for i in derivative:
  bias=bias-(0.05*i)
print(weights)
print(bias)
# Out:
# [[0.09737868]
#  [0.29692476]]
# [0.18392691]

# %%
pred=np.array([1,0])
result = np.dot(pred,weights)+bias
res = sigmoid_func(result)
print(res)
# Out:
# [0.56986628]

# %%
pred=np.array([1,1])
result = np.dot(pred,weights)+bias
res = sigmoid_func(result)
print(res)
# Out:
# [0.64066011]

# %%
pred=np.array([0,0])
result = np.dot(pred,weights)+bias
res = sigmoid_func(result)

print(res)
# Out:
# [0.54585254]

# %%
pred=np.array([0,1])
result = np.dot(pred,weights)+bias
res = sigmoid_func(result)
print(res)
# Out:
# [0.61794897]
